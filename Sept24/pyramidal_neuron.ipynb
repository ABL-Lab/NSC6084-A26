# %% [markdown]
# # A multi-compartmental model of a pyramidal neuron

# %% [markdown]
# ## Step 1: Setup

# %%
# Setup inline plotting
#%matplotlib widget
# %matplotlib inline
import matplotlib.pyplot as plt
#import matplotlib
#matplotlib.rcParams['path.simplify'] = False

# %%
# For Google Colab, this line installs NEURON
# !pip install neuron quantities neurom

# %%
# !pip install neurom
# Out:
# Collecting neurom
#   Using cached neurom-4.0.5.tar.gz (536 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: click>=7.0 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (8.5.0)
# Requirement already satisfied: matplotlib>=3.2.1 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (3.11.1)
# Collecting morphio>=3.3.6 (from neurom)
#   Downloading morphio-3.5.0-cp314-cp314-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.8.0 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (2.5.2)
# Requirement already satisfied: pandas>=1.0.5 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (3.0.5)
# Requirement already satisfied: pyyaml>=3.10 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (6.0.3)
# Requirement already satisfied: scipy>=1.2.0 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (1.18.0)
# Collecting tqdm>=4.8.4 (from neurom)
#   Using cached tqdm-4.70.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: cached_property>=1.5.1 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from neurom) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from matplotlib>=3.2.1->neurom) (2.9.0.post0)
# Collecting h5py (from morphio>=3.3.6->neurom)
#   Downloading h5py-3.16.0-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: tzdata in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from pandas>=1.0.5->neurom) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.1->neurom) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\emuller\miniconda3\envs\nsc6084_A26\Lib\site-packages (from tqdm>=4.8.4->neurom) (0.4.6)
# Downloading morphio-3.5.0-cp314-cp314-win_amd64.whl (857 kB)
#    ---------------------------------------- 0.0/857.4 kB ? eta -:--:--
#    ---------------------------------------- 857.4/857.4 kB 19.5 MB/s  0:00:00
# Using cached tqdm-4.70.1-py3-none-any.whl (80 kB)
# Downloading h5py-3.16.0-cp314-cp314-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 25.3 MB/s  0:00:00
# Building wheels for collected packages: neurom
#   Building wheel for neurom (pyproject.toml): started
#   Building wheel for neurom (pyproject.toml): finished with status 'done'
#   Created wheel for neurom: filename=neurom-4.0.5-py3-none-any.whl size=110156 sha256=77a7a6f24e36952c9c2a052c4efc840e6f29ae57c403c0504f2c7ac9440e0e15
#   Stored in directory: c:\users\emuller\appdata\local\pip\cache\wheels\03\fc\83\e0e9c71f7120cef5a6789cdea23316db075c458b5ccdd03434
# Successfully built neurom
# Installing collected packages: tqdm, h5py, morphio, neurom
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    ---------- ----------------------------- 1/4 [h5py]
#    -------------------- ------------------- 2/4 [morphio]
#    ------------------------------ --------- 3/4 [neurom]
#    ------------------------------ --------- 3/4 [neurom]
#    ------------------------------ --------- 3/4 [neurom]
#    ---------------------------------------- 4/4 [neurom]
#
# Successfully installed h5py-3.16.0 morphio-3.5.0 neurom-4.0.5 tqdm-4.70.1

# %%
# We will let this library handle unit conversion for us
import quantities as pq
from quantities import um, nS, mV, cm, ms, nA, S, uF, Hz, degrees, s, MOhm, mS, mm, Ohm

# %%
# Import and initialize NEURON
import neuron
from neuron import h
h.load_file("stdrun.hoc")
h.load_file("import3d.hoc")
#h.load_file("stdlib.hoc") # need geom_nseg
# Out:
# 1.0

# %%
# Import other modules we need
import numpy as np
from tqdm import tqdm
import time

# %%
import neurom as nm

# %%
from neurom.view import matplotlib_impl, matplotlib_utils

# %%
morph = nm.load_morphology('data/morphology.asc')

# %%
# instead of: viewer.draw(m)
matplotlib_impl.plot_morph(morph)
plt.xlabel(r"x ($\rm{\mu m}$)") 
plt.ylabel(r"y ($\rm{\mu m}$)")
# Out:
# Text(0, 0.5, 'y ($\\rm{\\mu m}$)')

# %%
len(morph.sections)
# Out:
# 487

# %%
len(morph.segments)
# Out:
# 13723

# %%
len(morph.neurites)
# Out:
# 9

# %%
# instead of: viewer.draw(m, mode='3d')
#matplotlib_impl.plot_morph3d(morph)

# %%
# instead of: viewer.draw(m, mode='dendrogram')
matplotlib_impl.plot_dendrogram(morph)

# %% [markdown]
# ## Step 2: Define the circuit

# %%
# constants
h.dt = 0.025
h.celsius = 34

# %%
def rerun_sim(tstop, tskip=0, v_init=-84.0, viz=False, steps=50, framerate=None):
    if framerate:
        dt = 1.0/framerate
    else:
        dt = None
    h.finitialize( float(v_init) )
    h.continuerun( float(tskip * ms) )
    for t in tqdm(np.linspace(tskip,tstop,steps)):
        t1 = time.time()
        h.continuerun( float(t * ms) )
        if viz==True:
            sp.flush()
        t2 = time.time()
        if dt:
            wait = dt-(t2-t1)
            if wait > 0:
                time.sleep(wait)

# %%
class MyCell:
    def __init__(self):
        """ Create the neuron, load the morphology, replace the axon with a stub, 
        configure nseg for each compartment
        """
        # This idiom below imports the morphology file and instaniates it as h.Sections
        morph_reader = h.Import3d_Neurolucida3()
        morph_reader.input('data/morphology.asc')
        i3d = h.Import3d_GUI(morph_reader, 0)
        i3d.instantiate(self)
        
        self.replace_axon()
        self.geom_nseg()
        self.check_diameters()
        
        # Alias for readability 
        self.basal = self.dend
        self.apical = self.apic
        self.axonal = self.axon
        
    def geom_nseg(self):
        """ Setup the nseg parameter for all sections
        Results in about 2 compartments per 40um
        """
        for sec in self.soma[0].wholetree():
            sec.nseg = int((sec.L/(0.1*h.lambda_f(2500))+.9)/2)*2 + 1
            #sec.nseg = int(sec.L/40)*2 + 1
    
    def check_diameters(self):
        """ Check there are no small diameter sections"""
        for sec in self.dend:
            if sec.diam<0.001:
                raise ValueError("diam=%f at section '%s'" % (sec.diam, sec.name()))
        
        for sec in self.apic:
            if sec.diam<0.001:
                raise ValueError("diam=%f at section '%s'" % (sec.diam, sec.name()))                    
    
    def replace_axon(self):
        """ We will not simulate the axon, 
        so this function deletes it and replaces it with a stub with same diameter """
        # Find the axonal section that connects to the soma
        axon_root = [x for x in self.soma[0].children() if x in self.axon]
        # There should be only one for this morphology
        assert len(axon_root)==1
        axon_root = axon_root[0]
        
        # Get diameter
        d = axon_root(0.0).diam
        
        # Delete all axon sections
        for sec in self.axon:
            h.delete_section(sec=sec)
        
        # Create new axon
        axon = h.Section()
        self.axon = [axon]
        axon.L = 60                                                              
        axon.diam = d   
        
        # Connect it to the some
        axon.connect(self.soma[0](1.0),0.0)

# %%
m = MyCell()
# Out:
# 14982 lines read

# %%
print('%d apic sections' % len(m.apic))
print('%d basal sections' % len(m.dend))
print('%d somatic sections' % len(m.soma))
print('%d axonal sections' % len(m.axon))
# Out:
# 150 apic sections
# 83 basal sections
# 1 somatic sections
# 1 axonal sections

# %%
# An alias for the soma
soma = m.soma[0]

# %% [markdown]
# #### Count the number of sections and segments

# %%
num_segments = sum([d.nseg for d in soma.wholetree()])

# %%
num_segments
# Out:
# 607

# %%
num_sections =0
for sec in soma.wholetree():
    num_sections+=1

# %%
num_sections
# Out:
# 235

# %% [markdown]
# #### Visualize the neuron within NEURON!

# %%
# Only works if Jupyter & NEURON are running locally, I imagine.
#from neuron import gui

sp = h.PlotShape()

# %%
sp.show(1)
sp.show(0)  # show diameters
# Out:
# 1

# %% [markdown]
# ### Query NEURON for soma.L, soma.diam, area and volume

# %%
soma.L, soma.diam
# Out:
# (23.545965481667047, 15.631430640804869)

# %%
volume = soma(0.5).volume() * um**3

# %%
area = soma(0.5).area() * um**2

# %%
area
# Out:
# array(1360.8852786) * um**2

# %%
volume
# Out:
# array(4846.91054) * um**3

# %% [markdown]
# ### Assign the membrane capacitance, resistivity and passive properties "everywhere"

# %%
h.units("cm")  # Query the expected units
# Out:
# 'uF/cm2'

# %%
h.units("Ra")
# Out:
# 'ohm-cm'

# %%
specific_membrane_capacitance = 1 * uF/cm**2

# %%
# This will look over sections in the whole tree (axons, dendrites, apical dendrites) connected/attached to the soma 
for sec in soma.wholetree():
    sec.insert("pas")
    sec.e_pas = -75.0
    sec.g_pas = 3e-5
    sec.cm = specific_membrane_capacitance #  specific membrane capacitance (micro Farads / cm^2)
    sec.Ra = 100 * Ohm*cm # resistivity

# %%
# This is to compensate for spines (which we don't model explicitly, but effect capacitance considerably)
for sec in m.basal+m.apical:
    sec.cm = 2

# %% [markdown]
# ### Assign the channels in the various regions of the neuron

# %%
for sec in m.basal+m.apical+m.soma:
    sec.insert("Ih")

# %%
# Na and K channels
for sec in m.apical:
    sec.insert("Im")

for sec in m.soma+m.apical:
    sec.insert("NaTs2_t")
    
for sec in m.axonal:
    sec.insert("Nap_Et2")
    sec.insert("K_Pst")
    sec.insert("K_Tst")
    sec.insert("NaTa_t")
    
for sec in m.axonal+m.soma+m.apical:
    sec.insert("SKv3_1")

# %%
# Calcium and SK channels
for sec in m.soma+m.axonal:
    sec.insert("Ca_HVA")
    sec.insert("SK_E2")
    sec.insert("Ca_LVAst")
    sec.insert("CaDynamics_E2")

# %% [markdown]
# ### Parameterize the channel conductances
# Note, these values come from an external data-driven optimization process to fit neuronal firing features to experimental data <br>
# See: https://www.frontiersin.org/articles/10.3389/fninf.2016.00017/full

# %% [markdown]
# #### Define and apply an exponential distribution of Ih channel conductances in the apical dendrite

# %%
def distribute_Ih(x):
    """Spatial specific conductance distribution of Ih channels
    x (in um) is the path distance distance to the soma
    """
    from math import exp
    return 6.9568e-5*(2.4*exp(x*0.003100) - 1)

# %%
for sec in m.apical:
    for seg in sec:
        x = h.distance(soma(0.0),seg)
        seg.gIhbar_Ih = distribute_Ih(x)

# %% [markdown]
# #### All other channels have constant conductances

# %%
for sec in m.basal+m.soma:
    sec.gIhbar_Ih = 8e-5

# %%
for sec in m.apical:
    sec.gNaTs2_tbar_NaTs2_t = 0.026145
    sec.gSKv3_1bar_SKv3_1 = 0.004226
    sec.gImbar_Im = 0.000143

# %%
for sec in m.axonal:
    sec.gNaTa_tbar_NaTa_t = 3.137968
    sec.gK_Tstbar_K_Tst = 0.089259
    sec.gamma_CaDynamics_E2 = 0.002910
    sec.gNap_Et2bar_Nap_Et2 = 0.006827
    sec.gSK_E2bar_SK_E2 = 0.007104
    sec.gCa_HVAbar_Ca_HVA = 0.000990
    sec.gK_Pstbar_K_Pst = 0.973538
    sec.gSKv3_1bar_SKv3_1 = 1.021945
    sec.decay_CaDynamics_E2 = 287.198731
    sec.gCa_LVAstbar_Ca_LVAst = 0.008752

# %%
for sec in m.soma:
    sec.gamma_CaDynamics_E2 = 0.000609
    sec.gSKv3_1bar_SKv3_1 = 0.303472
    sec.gSK_E2bar_SK_E2 = 0.008407
    sec.gCa_HVAbar_Ca_HVA = 0.000994
    sec.gNaTs2_tbar_NaTs2_t = 0.983955
    sec.decay_CaDynamics_E2 = 210.485284
    sec.gCa_LVAstbar_Ca_LVAst = 0.000333

# %%
for sec in m.soma+m.apical+m.axon:
    sec.ena = 50
    sec.ek = -85

# %% [markdown]
# ### Add soma current pulse

# %%
step_amp = [0.4299372, 0.4657653, 0.5015934]
hyp_amp = -0.193481

# %%
stim = h.IClamp(soma(0.5))

# %%
stim.delay = 500 * ms
stim.dur = 1000 * ms
stim.amp = step_amp[0]

# %%
hyp_iclamp = h.IClamp(soma(0.5))

# %%
hyp_iclamp.delay = 0 * ms
hyp_iclamp.dur = 5000 * ms  
hyp_iclamp.amp = hyp_amp * nA

# %% [markdown]
# ## Step 3: Run the simulation

# %% [markdown]
# ### Define recordings of simulation variables

# %%
rec_v = h.Vector().record(soma(0.5)._ref_v)
rec_t = h.Vector().record(h._ref_t)

# %%
rerun_sim(tstop=1500, tskip=500, viz=True, steps=1000, framerate=20)
# For Shape plot viz
# Out:
# 100%|██████████| 1000/1000 [01:15<00:00, 13.19it/s]

# %%
sp.color?
# Out:
# Signature:   sp.color(*args, **kwargs)
# Type:        HocObject
# String form: PlotShape[0].color()
# File:        c:\nrn\lib\python\neuron\hoc.cp314-win_amd64.pyd
# Docstring:
# Syntax:
#     ``shape.color(i, sec=sec)``
#
# Description:
#     colors the specified section according to color index
#     (index same as specified in Graph class). If there are several
#     sections to color it is more efficient to make a SectionList and
#     use \ ``.color_list``

# %%
#rerun_sim(tstop=2000, steps=1000)

# %%
vs = []
for amp in step_amp:
    stim.amp = amp
    rerun_sim(tstop=2000, steps=1000)
    vs.append(np.array(rec_v))
# Out:
# 100%|██████████| 1000/1000 [02:23<00:00,  6.99it/s]
# 100%|██████████| 1000/1000 [02:35<00:00,  6.42it/s]
# 100%|██████████| 1000/1000 [03:02<00:00,  5.48it/s]

# %% [markdown]
# ## Step 4: Plot the results

# %%
plt.figure()
plt.plot(rec_t, vs[0], label="py version")

# %%
plt.figure()
plt.plot(rec_t, vs[1], label="py version")

# %%
plt.figure()
plt.plot(rec_t, vs[2], label="py version")
